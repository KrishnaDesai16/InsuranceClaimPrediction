# %%
import pandas as pd
import numpy as np
import datetime
from pandas import datetime
import matplotlib.pyplot as plt
import seaborn as sb
import plotly as py
from plotly.offline import iplot
import plotly.express as px 
import cufflinks as cf

py.offline.init_notebook_mode(connected=True)
cf.go_offline()
pd.set_option('display.max_columns',59)
plt.style.use('ggplot')
# Out:
# C:\Users\JESAL\anaconda3\lib\site-packages\ipykernel_launcher.py:4: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   after removing the cwd from sys.path.
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
# ...

# %%
from sklearn.metrics import accuracy_score,confusion_matrix
from sklearn.preprocessing import StandardScaler,MinMaxScaler
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv('train.csv')

# %% [markdown]
# # Insights of Data

# %% [markdown]
# - feature with postfix 'bin' are binary features
# - feature with post_fix 'cat' are  categorical features
# - feature's name are tagged with ind, reg, car, calc.
# - Values of -1 indicate that the feature is missing from the observation.
# - The target columns signifies whether or not a claim was filed for that policy holder.

# %%
df.tail()
# Out:
#              id  target  ps_ind_01  ps_ind_02_cat  ps_ind_03  ps_ind_04_cat  \
# 595207  1488013       0          3              1         10              0
# 595208  1488016       0          5              1          3              0
# 595209  1488017       0          1              1         10              0
# 595210  1488021       0          5              2          3              1
# 595211  1488027       0          0              1          8              0
#
#         ps_ind_05_cat  ps_ind_06_bin  ps_ind_07_bin  ps_ind_08_bin  \
# 595207              0              0              0              0
# 595208              0              0              0              0
# 595209              0              1              0              0
# 595210              0              0              0              1
# 595211              0              1              0              0
#
#         ps_ind_09_bin  ps_ind_10_bin  ps_ind_11_bin  ps_ind_12_bin  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 595212 entries, 0 to 595211
# Data columns (total 59 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   id              595212 non-null  int64
#  1   target          595212 non-null  int64
#  2   ps_ind_01       595212 non-null  int64
#  3   ps_ind_02_cat   595212 non-null  int64
#  4   ps_ind_03       595212 non-null  int64
#  5   ps_ind_04_cat   595212 non-null  int64
#  6   ps_ind_05_cat   595212 non-null  int64
#  7   ps_ind_06_bin   595212 non-null  int64
#  8   ps_ind_07_bin   595212 non-null  int64
#  9   ps_ind_08_bin   595212 non-null  int64
#  10  ps_ind_09_bin   595212 non-null  int64
#  11  ps_ind_10_bin   595212 non-null  int64
#  12  ps_ind_11_bin   595212 non-null  int64
#  13  ps_ind_12_bin   595212 non-null  int64
#  14  ps_ind_13_bin   595212 non-null  int64
#  15  ps_ind_14       595212 non-null  int64
#  16  ps_ind_15       595212 non-null  int64
# ...

# %%
df.describe()
# Out:
#                  id         target      ps_ind_01  ps_ind_02_cat  \
# count  5.952120e+05  595212.000000  595212.000000  595212.000000
# mean   7.438036e+05       0.036448       1.900378       1.358943
# std    4.293678e+05       0.187401       1.983789       0.664594
# min    7.000000e+00       0.000000       0.000000      -1.000000
# 25%    3.719915e+05       0.000000       0.000000       1.000000
# 50%    7.435475e+05       0.000000       1.000000       1.000000
# 75%    1.115549e+06       0.000000       3.000000       2.000000
# max    1.488027e+06       1.000000       7.000000       4.000000
#
#            ps_ind_03  ps_ind_04_cat  ps_ind_05_cat  ps_ind_06_bin  \
# count  595212.000000  595212.000000  595212.000000  595212.000000
# mean        4.423318       0.416794       0.405188       0.393742
# std         2.699902       0.493311       1.350642       0.488579
# min         0.000000      -1.000000      -1.000000       0.000000
# ...

# %% [markdown]
# - there are 59 features in dataset.
# - Values of -1 indicate that the feature is missing from the observation.
# -

# %% [markdown]
# #  individual visualisation
# 1. binary features--->part 1,part 2
# 2. categorical features---part 1,part 2
# 3. int features-->ind and car
# 4. int features-->calc
# 5. float festures-->reg  and calc
# 6. float features -->car
# 7. target variable

# %%
binary_features=[feature for feature in df.columns if 'bin' in feature]
categorical_feature=[feature for feature in df.columns if 'cat' in feature]
integer_feature_part1=['ps_ind_01','ps_ind_03','ps_ind_14','ps_ind_15','ps_car_11']
integer_feature_part2=[feature for feature in df.columns if 'calc' in feature and df[feature].dtype=='int64' and 'bin' not in feature]
floating_feature_part1=[feature for feature in df.columns if 'reg' in feature or  'calc' in feature and df[feature].dtype=='float64']
floating_feature_part2=[feature for feature in df.columns if 'car'in feature and df[feature].dtype=='float64']
integer_feature_part2
# Out:
# ['ps_calc_04',
#  'ps_calc_05',
#  'ps_calc_06',
#  'ps_calc_07',
#  'ps_calc_08',
#  'ps_calc_09',
#  'ps_calc_10',
#  'ps_calc_11',
#  'ps_calc_12',
#  'ps_calc_13',
#  'ps_calc_14']

# %%
print('# binary features are:',len(binary_features))
print('# categorical features are:',len(categorical_feature))
print('# int features are:',len(integer_feature_part1)+len(integer_feature_part2))
print('# float features are:',len(floating_feature_part1)+len(floating_feature_part2))
# Out:
# # binary features are: 17
# # categorical features are: 14
# # int features are: 16
# # float features are: 10

# %% [markdown]
# # categorical features

# %%
#fig,axs=plt.subplots(3,6,figsize(9,3),sharey=True)
plt.figure(figsize=(10,30))
j=0
for i in categorical_feature:
    j +=1
    plt.subplot(8,2,j)
    sb.countplot(x=df[i],palette="hls")
plt.show()

# %% [markdown]
# - some of features have low levels wherease feature 11 shared by cat and int features
# - feature 3 and 5 have more # of missing values(-1).
# - some feature has law varicance that provide less information about data,that can be removed.

# %% [markdown]
# # binary features

# %%
fig, ax = plt.subplots(6,3, figsize=(20,30))
for variable, subplot in zip(binary_features, ax.flatten()):
    sb.countplot(df[variable], ax=subplot,palette='rocket')
    for label in subplot.get_xticklabels():
        label.set_rotation(90)

# %% [markdown]
# - most of the binary features are unbalanced with FALSE accounting for vast majority case.
# - features 10 to 13 are perticulary FALSE.

# %% [markdown]
# # integer_feature_part1: 'ind' and 'car'

# %%
fig, ax = plt.subplots(2,3, figsize=(25,15))
for variable, subplot in zip(integer_feature_part1,ax.flatten()):
    sb.countplot(df[variable], ax=subplot,palette='Set2')
    for label in subplot.get_xticklabels():
        label.set_rotation(90)

# %% [markdown]
# - 'ind' and 'car' groups are best visualized in bar plot,because the ranges are not very large.
# -  unbalance found in  feature 11 and 14,where  value 3 and 0 is most dominating respectively

# %% [markdown]
# # integer_feature_part2 : 'calc'

# %%
plt.figure(figsize=(25,50))
j=0
for i in integer_feature_part2:
    j +=1
    plt.subplot(8,3,j)
    sb.countplot(x=df[i],palette="hls")

# %% [markdown]
# - feature 10,11,14 seems close to normal distribution curve,probably tail is towards the larger value.
# - another features present the frequency.

# %% [markdown]
# # float features:'reg'  and 'calc'

# %%
plt.figure(figsize=(25,50))
j=0
for i in floating_feature_part1 :
    j +=1
    plt.subplot(8,3,j)
    plt.hist(df[i],color='skyblue')
    plt.xlabel(i)

# %% [markdown]
# - feature 'reg':1,2,3 are highly skwed from prominent value  of normal distribution
# - feature 'clac':1,2,3 clearly looks uniformly distributed

# %% [markdown]
# # float feature :'car'

# %%
plt.figure(figsize=(10,8))
j=0
for i in floating_feature_part2 :
    j +=1
    plt.subplot(2,2,j)
    plt.hist(df[i],color='skyblue')
    plt.xlabel(i)

# %% [markdown]
# - We find that the two features on the left show interesting sub-structure in their distributions, while ps_car_15 appears to take only quite distinct values until after ps_car_15 == 3 when the gaps decrease notably.

# %% [markdown]
# # target variable

# %%
plt.figure(figsize=(10,6))
sb.countplot(df['target'])

# %% [markdown]
# - target feature looks imbalanced with majority of not claimed :0

# %%
counts=df['target'].value_counts()
counts
# Out:
# 0    573518
# 1     21694
# Name: target, dtype: int64

# %%
NO_Claimed=len(df[df.target==0])
Claimed=len(df[df.target==1])
print('# of claimed insurance:',Claimed)
print('# of not Claimed insurance:',NO_Claimed)
#target feature has imbalaced
# Out:
# # of claimed insurance: 21694
# # of not Claimed insurance: 573518

# %%
labels=['NO Claimed','Claimed']
explode=[0,0.1]
counts.plot.pie(explode=explode, labels=labels,figsize=(10,5),fontsize=20,autopct='%.2f',legend=True)
plt.show()

# %% [markdown]
# # Claim rates for individual features

# %%
plt.figure(figsize=(10,30))
j=0
for i in categorical_feature:
    j +=1
    plt.subplot(8,2,j)
    sb.barplot(x=df[i],y=df['target'],palette="hls")
plt.show()

# %% [markdown]
# - majority features have large amount of missing values(-1).
# - ind_04_cat and p_car_01_cat feature provide less information
